# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
df = pd.read_csv('Indeed4.csv')
plt.figure(figsize=(14,6))
salary_df = df[df['Salary group'] != 'Not Mentioned']
sns.countplot(data=salary_df, x=salary_df['Salary group'], order = ['Below 10000','10000-19999','20000-29999','30000-39999','40000-49999','50000-59999','60000-69999','70000 or above']).set_title('Salary Distribution in Singapore')
df[df['Salary group'] != 'Not Mentioned']['Salary group'].value_counts()
# Out:
# 20000-29999       104
# 30000-39999        86
# 40000-49999        51
# 10000-19999        32
# 50000-59999        23
# 70000 or above     15
# 60000-69999         9
# Below 10000         4
# Name: Salary group, dtype: int64

# %%
fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(221) 
ax2 = fig.add_subplot(222)
df['English'].value_counts().plot(kind='pie',autopct='%.2f%%',title='Language Requirement for data job in SG', ax=ax)
df['Chinese'].value_counts().plot(kind='pie',autopct='%.2f%%',title='Language Requirement for data job in SG', ax=ax2)

# %%
fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(221) 
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
colors = ['mistyrose','plum','sandybrown','lemonchiffon','lightsalmon']
label = ['Bachelor','PhD','Higher Diploma','Diploma','Master']

df[(df['Job category'] == 'Data analyst') & (df['Minimum education level'] != 'Not specified')]['Minimum education level'].value_counts().plot(kind='pie',autopct='%.2f%%',title='Minimum Education Level for Data Analyst in SG', ax=ax, colors=colors, labels=label)
df[(df['Job category'] == 'Data analyst') & (df['Maximum education level'] != 'Not specified')]['Maximum education level'].value_counts().plot(kind='pie',autopct='%.2f%%',title='Maximum Education Level for Data Analyst in SG', ax=ax2, colors=colors, labels=label)
df[(df['Job category'] == 'Data scientist')  & (df['Minimum education level'] != 'Not specified')]['Minimum education level'].value_counts().plot(kind='pie',autopct='%.2f%%',title='Minimum Education Level for Data Scientist in SG', ax=ax3, colors=colors, labels=label)
df[(df['Job category'] == 'Data scientist') & (df['Maximum education level'] != 'Not specified')]['Maximum education level'].value_counts().plot(kind='pie',autopct='%.2f%%',title='Maximum Education Level for Data Scientist in ', ax=ax4, colors=colors, labels=label)

# %%
fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(221) 
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
label = ['Y','N']
color = ['darkorange','moccasin']
df[df['Job category'] == 'Data analyst']['Python'].value_counts().plot(kind='pie',autopct='%.2f%%',title='Visualisation skills of SG Data Analyst', ax=ax, labels=label,colors=color)
df[df['Job category'] == 'Data analyst']['Programming tool'].value_counts().plot(kind='pie',autopct='%.2f%%',title='Programming skills of SG Data Analyst', ax=ax2,labels=label,colors=color)
df[df['Job category'] == 'Data scientist']['Visualisation tool'].value_counts().plot(kind='pie',autopct='%.2f%%',title='Visualisation skills of SG Data Scientist', ax=ax3,labels=label,colors=color)
df[df['Job category'] == 'Data scientist']['Programming tool'].value_counts().plot(kind='pie',autopct='%.2f%%',title='Programming skills of SG Data Scientist', ax=ax4,labels=label,colors=color)

# %%
df['Chinese'].str.contains('Y').sum()
# Out:
# 33

# %%
df['Chinese']
# Out:
# 0       N
# 1       N
# 2       N
# 3       N
# 4       N
#        ..
# 1116    N
# 1117    N
# 1118    N
# 1119    N
# 1120    Y
# Name: Chinese, Length: 1121, dtype: object

# %%
lang_df = pd.melt(df, id_vars =['Job category'], value_vars =['English', 'Chinese']) 
lang_df = lang_df[lang_df['value'].notnull()]
lang_df
sns.countplot(data=lang_df,x=lang_df['Job category'],hue='variable').set_title('Language Requirement in SG')
# Out:
# Text(0.5, 1.0, 'Language Requirement in SG')

# %%
fig = plt.figure(figsize=(20,10))
skill_df = pd.melt(df, id_vars =['Job category'], value_vars =['Python','R','Excel','C++','C','C#','SQL','MySQL']) 
skill_df = skill_df[skill_df['value'].notnull()]
sns.countplot(data=skill_df,x=skill_df['Job category'],hue=skill_df['variable']).set_title('Programming Requirement in SG')
# Out:
# Text(0.5, 1.0, 'Programming Requirement in SG')

# %%
fig = plt.figure(figsize=(20,10))
visual_df = pd.melt(df,id_vars=['Job category'], value_vars=['Power BI','Qlik','alteryx','Tableau'])
visual_df = visual_df[visual_df['value'].notnull()]
sns.countplot(data=visual_df,x=visual_df['Job category'],hue=visual_df['variable']).set_title('Visualisation Requirement in SG')
# Out:
# Text(0.5, 1.0, 'Visualisation Requirement in SG')
